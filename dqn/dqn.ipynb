# %%
# %load_ext autoreload
# %autoreload 2
import gym
from dqn import agent,utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import torch,torchvision
from PIL import Image
import matplotlib.pylab as plt
# %matplotlib inline
import numpy as np

# %%
env = gym.envs.make("BreakoutDeterministic-v4")
_ =env.reset()
bob = agent.DQNAgent()

# %%
bob.train(env,num_episodes=5000)
# Out:
# 100%|██████████| 5001/5001 [4:04:41<00:00,  2.68s/it]
# [<Box: {'steps': 131, 'reward': 0.0}>,
#  <Box: {'steps': 218, 'reward': 2.0}>,
#  <Box: {'steps': 309, 'reward': 4.0}>,
#  <Box: {'steps': 158, 'reward': 1.0}>,
#  <Box: {'steps': 147, 'reward': 0.0}>,
#  <Box: {'steps': 139, 'reward': 0.0}>,
#  <Box: {'steps': 266, 'reward': 3.0}>,
#  <Box: {'steps': 128, 'reward': 0.0}>,
#  <Box: {'steps': 365, 'reward': 5.0}>,
#  <Box: {'steps': 172, 'reward': 1.0}>,
#  <Box: {'steps': 198, 'reward': 1.0}>,
#  <Box: {'steps': 136, 'reward': 0.0}>,
#  <Box: {'steps': 138, 'reward': 0.0}>,
#  <Box: {'steps': 200, 'reward': 2.0}>,
#  <Box: {'steps': 230, 'reward': 3.0}>,
#  <Box: {'steps': 253, 'reward': 3.0}>,
#  <Box: {'steps': 204, 'reward': 2.0}>,
#  <Box: {'steps': 194, 'reward': 1.0}>,
#  <Box: {'steps': 130, 'reward': 0.0}>,
#  <Box: {'steps': 184, 'reward': 1.0}>,
#  <Box: {'steps': 135, 'reward': 0.0}>,
#  <Box: {'steps': 245, 'reward': 2.0}>,
#  <Box: {'steps': 343, 'reward': 5.0}>,
# ...
